# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvi-Gajula/Projects/blob/main/AgriBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chardet

# %%
import chardet

# %%
with open('/content/balaram.csv', 'rb') as f:
    encoding = chardet.detect(f.read())['encoding']

# %%
df = pd.read_csv('/content/balaram.csv', encoding=encoding)
df
# Out:
#    crop_name seed_name                            rainfall  \
# 0       Rice     Madhu   A monthly rainfall of 100-200 mm.
# 1       Rice  Mahaveer    A monthly rainfall of 100-200 mm
# 2       Rice    Puspha    A monthly rainfall of 100-200 mm
# 3       Rice   Abilash    A monthly rainfall of 100-200 mm
# 4       Rice     Intan    A monthly rainfall of 100-200 mm
# ..       ...       ...                                 ...
# 70       NaN       NaN                                 NaN
# 71       NaN       NaN                                 NaN
# 72       NaN       NaN                                 NaN
# 73       NaN       NaN                                 NaN
# 74       NaN       NaN                                 NaN
#
#                                                  soil  \
# 0   This rice is suitable for Red soil and Black c...
# 1   This rice is suitable for Red soil and Black c...
# 2   This rice is suitable for Red soil and Black c...
# ...

# %%
# Count the missing values in each column
missing_values = df.isnull().sum()

# Print the missing values per column
print(missing_values)
# Out:
# crop_name           7
# seed_name           7
# rainfall            7
# soil                7
# irrigation          7
# sowing_time         7
# maturity_time       7
# seed_rate           7
# avg_yeild           7
# fertilizer          7
# pesticide           7
# location            6
# special_feature     7
# Unnamed: 13        74
# dtype: int64

# %%
# Drop the last column
df.drop(df.columns[-1], axis=1, inplace=True)

# %%
df
# Out:
#    crop_name seed_name                            rainfall  \
# 0       Rice     Madhu   A monthly rainfall of 100-200 mm.
# 1       Rice  Mahaveer    A monthly rainfall of 100-200 mm
# 2       Rice    Puspha    A monthly rainfall of 100-200 mm
# 3       Rice   Abilash    A monthly rainfall of 100-200 mm
# 4       Rice     Intan    A monthly rainfall of 100-200 mm
# ..       ...       ...                                 ...
# 70       NaN       NaN                                 NaN
# 71       NaN       NaN                                 NaN
# 72       NaN       NaN                                 NaN
# 73       NaN       NaN                                 NaN
# 74       NaN       NaN                                 NaN
#
#                                                  soil  \
# 0   This rice is suitable for Red soil and Black c...
# 1   This rice is suitable for Red soil and Black c...
# 2   This rice is suitable for Red soil and Black c...
# ...

# %%
# Drop rows with missing values
df.dropna(inplace=True)

df
# Out:
#    crop_name            seed_name  \
# 0       Rice                Madhu
# 1       Rice             Mahaveer
# 2       Rice               Puspha
# 3       Rice              Abilash
# 4       Rice                Intan
# ..       ...                  ...
# 63     Wheat  DDK 1025 (Dicoccum)
# 64     Wheat               GW 322
# 65     Wheat     HD 2781 (Aditya)
# 66     Wheat     HD 2833 (Tripti)
# 67     Wheat              HUW 510
#
#                                              rainfall  \
# 0                   A monthly rainfall of 100-200 mm.
# 1                    A monthly rainfall of 100-200 mm
# 2                    A monthly rainfall of 100-200 mm
# 3                    A monthly rainfall of 100-200 mm
# 4                    A monthly rainfall of 100-200 mm
# ..                                                ...
# 63  The amount of rainfall required for wheat cult...
# 64  The amount of rainfall required for wheat cult...
# 65  The amount of rainfall required for wheat cult...
# ...

# %%
print(df[categorical_columns].shape)
# Out:
# (68, 10)

# %%
print(df[categorical_columns].isnull().sum())
# Out:
# crop_name          0
# seed_name          0
# soil               0
# irrigation         0
# sowing_time        0
# maturity_time      0
# fertilizer         0
# pesticide          0
# location           0
# special_feature    0
# dtype: int64

# %%
print(df[categorical_columns].dtypes)
# Out:
# crop_name          object
# seed_name          object
# soil               object
# irrigation         object
# sowing_time        object
# maturity_time      object
# fertilizer         object
# pesticide          object
# location           object
# special_feature    object
# dtype: object

# %%
categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# %%
df
# Out:
#     crop_name  seed_name  rainfall  soil  irrigation  sowing_time  \
# 0          10         47         0    10           0           14
# 1          10         48        15    10           0           15
# 2          10         56        15    10           0           16
# 3          10          2        15    10           0           11
# 4          10         40        15    10           0           13
# ..        ...        ...       ...   ...         ...          ...
# 63         14         22        14    12           4            1
# 64         14         25        14    12           4            1
# 65         14         31        14    12           4            1
# 66         14         32        14    12           4            1
# 67         14         34        14    12           4            1
#
#     maturity_time  seed_rate  avg_yeild  fertilizer  pesticide  location  \
# 0              16          9          0           8          8        10
# ...

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()
