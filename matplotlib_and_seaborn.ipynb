# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanvi-Gajula/Projects/blob/main/matplotlib_and_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Tanvi Gajula
# Reg no: 21MIA1076

# %% [markdown]
# Seaborn:

# %%
import pandas as pd
#read the content which available in csv format
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['shopping.csv']))
df
# Out:
#      <input type="file" id="files-e25419c4-fbe2-4cf0-b24d-346a71f674c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e25419c4-fbe2-4cf0-b24d-346a71f674c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Importing seaborn modifies the default matplotlib color schemes
# and plot styles to improve readability and aesthetics. Even if you do
# not use the seaborn API, you may prefer to import seaborn as a
# simple way to improve the visual aesthetics of general matplotlib
# plots.

# %% [markdown]
# 1)Display the product id count for all titles

# %%
tips = pd.read_csv('shopping.csv')
shopping_counts = pd.crosstab(tips['product_id'], tips['title'])
shopping_counts
# Out:
# title       Crew-Neck T-Shirt  Raglan T-Shirt  Retro T-Shirt  \
# product_id
# 10001                       0               0              0
# 10002                       0               8              0
# 10003                       0               0              6
# 10004                       0               0              0
# 10005                       8               0              0
#
# title       Sleeveless T-Shirt  V-Neck T-Shirt
# product_id
# 10001                        9               0
# 10002                        0               0
# 10003                        0               0
# 10004                        0               8
# 10005                        0               0

# %% [markdown]
# 2)Plot graph of product id and sku

# %%
import seaborn as sns
sns.barplot(x='product_id', y='sku', data=tips, orient='h')

# %% [markdown]
# 3)Plot the graph for product id, title, and description

# %%
#seaborn.barplot has a hue option that enables us to split by an additional categorical value
sns.barplot(x='product_id', y='title', hue='description', data=tips, orient='h')

# %% [markdown]
# 4)Plot a histogram graph of product id

# %%
tips['product_id'].plot.hist(bins=50)

# %% [markdown]
# 5)Plot a density graph for prices

# %%
tips['price'].plot.density()

# %% [markdown]
# 6)Plot a graph Concating 2 persons shopping bill prices

# %%
import numpy as np
#Concating 2 persons shopping bill prices and ploting the graph
comp1 = np.random.normal(100,150 , size=200)
comp2 = np.random.normal(250 , 350, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 7)Display the respective measures taken from shopping csv file

# %%
data = tips[['product_id', 'sort', 'rrp', 'price']]
trans_data = np.log(data).diff().dropna()

# %% [markdown]
# 8)Plot a graph of sort and rrp

# %%
# Importing libraries
import numpy as np
import seaborn as sns
# Selecting style as white,dark, whitegrid, darkgrid or ticks
sns.set(style="white")
# Generate a random univariate dataset of shopping prices 
rs = np.random.RandomState(10)
d = rs.normal(size=100)
# Plot a simple histogram and kde with binsize determined automatically
sns.distplot(d, kde=True, color="m")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 9)Plot graph without histogram using seaborn for random price of shoppings

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=40), hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 10)Plot a graph using histogram given 10 trials for brand to generate 10 items
#
# Binomial Distribution is a Discrete Distribution.
# It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.
# It has three parameters:
# n - number of trials.
# p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
# size - The shape of the returned array.

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Matplotlib:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['company_sales_data.csv']))
df
# Out:
#      <input type="file" id="files-6a1705ce-2846-435c-b021-3e3c2a87e49f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a1705ce-2846-435c-b021-3e3c2a87e49f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 11)Using the matplot graph show how much stock you have for that material in your market?

# %%
plt.figure(figsize = (10, 4))
#item name
x = ['Shirts', 'Jeans', 'Crop-Tops', 'T-shirts', 'Sarre']
y = [13, 10, 7, 8, 11]
#plotting of bar
plt.bar(x, y, color = 'g')
#X-axis and Y-axis
plt.xlabel('Items', fontsize =20 )
plt.ylabel('Number of Stock', fontsize = 20)
#Default fontsize of text using legend
plt.legend(['Stock-Information'])
#command for plot
plt.show()

# %% [markdown]
# 12)Plot a graph where you anayze the profit in a year?

# %%
#calling the profit list and month list from the csv file
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
#giving the lebel to the graph
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')
plt.xlabel('Month number')
plt.ylabel('Profit in Rs.')
plt.xticks(monthList)
plt.title('Market profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# 13)Show the profit of the market with the dotted line graph?

# %%
#calling the profit list and month list from the csv file
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
#giving the lebel to the graph also mentioning the style of the line of the graph
plt.plot(monthList, profitList, label = 'Profit data of last year', 
      color='r', linestyle='--')     
plt.xlabel('Month Number')
plt.ylabel('Profit in Rs.')
#giving the location to the lebel
plt.legend(loc='lower right')
plt.title(' Sales data of last year')
plt.xticks(monthList)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %% [markdown]
# 14)Display the number of units sold per month for shampo product using multiline plots.

# %%
#calling these information from file
monthList  = df ['month_number'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
#giving lebel name to the graph
plt.plot(monthList, shampooSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
#X-axis and Y-axis
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
#specifiying the location of the legend
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %% [markdown]
# 15) Read toothpaste sales data of each month and show it using a scatter plot?

# %%
#calling these information from file
monthList  = df ['month_number'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
#giving lebel name to the graph
plt.scatter(monthList, toothPasteSalesData, label = 'Tooth paste Sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
#specifiying the location of the legend
plt.legend(loc='upper left')
plt.title(' Tooth paste Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %% [markdown]
# 16)Calculate total sale data for last year for each product and show it using a Pie chart?

# %%
#calling this information from the csv file
monthList  = df ['month_number'].tolist()
#making lebels in the bar 
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), 
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]
#calling the pie graph
plt.pie(salesData, labels=labels,autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.title('Sales data')
plt.show()

# %% [markdown]
# 17)Read face cream and facewash product sales data and show it using the bar chart.

# %%
#calling this information from the csv file
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
#lebel to the graph
plt.bar([a-0.25 for a in monthList], faceCremSalesData, label = 'Face Cream sales data', align='edge')
plt.bar([a+0.25 for a in monthList], faceWashSalesData,  label = 'Face Wash sales data', align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and facecream sales data')
plt.show()

# %% [markdown]
# 18) Read the total profit of each month and show it using the histogram to see the most common profit ranges

# %%
#calling the information from csv file 
profitList = df ['total_profit'].tolist()
labels = ['low', 'average', 'Good', 'Best']
#setting the range
profit_range = [150000 , 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(profitList, profit_range, label = 'Profit data')
plt.xlabel('profit range in Rs')
plt.ylabel('Actual Profit in Rs')
plt.legend(loc='upper left')
plt.xticks(profit_range)
plt.title('Profit data')
plt.show()

# %% [markdown]
# 19)Make a graph where two year profit of the market is given ?

# %%
#city where the business is set up
city = ["delhi","chandigarh","ajmer"]
#information of year1 and year2
year1 =[20000,50000,10000]
year2=[10000,20000,15000]
plt.plot(city,year1)
plt.plot(city,year2)
plt.xlabel('City')
plt.ylabel('Profit in Rs.')
plt.title("Market-Information")
plt.show()

# %% [markdown]
# 20)Read Bathing soap facewash of all months and display it using the Subplot

# %%
#calling the function from the csv file
monthList  = df ['month_number'].tolist()
bathingsoap   = df ['bathingsoap'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
#plotting two graph
f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(monthList, bathingsoap, label = 'Bathingsoap Sales Data', color='k', marker='o', linewidth=3)
axarr[0].set_title('Sales data of  a Bathingsoap')
axarr[1].plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', color='r', marker='o', linewidth=3)
axarr[1].set_title('Sales data of  a facewash')

plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.show()
